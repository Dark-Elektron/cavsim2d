# %%
import sys
sys.path.append("..")
import numpy as np
import json
import matplotlib
import matplotlib.pyplot as plt
plt.ion()
# %matplotlib inline
from cavsim2d.cavity import Cavity, Cavities, OperationPoints, Pillbox
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
# pillbox parameters
n_cell, L, Req, Ri, S, L_bp, beampipe = 1, 310, 148, 48, 92, 92, 'both'

# create cavity
pill = Pillbox(n_cell, L, Req, Ri, S, L_bp, beampipe)
ax = pill.plot('geometry')

plt.show()

# %%
cavs = Cavities([])
# must first save cavities
cavs.save(files_path='D:\Dropbox\CavityDesignHub\MuCol_Study\SimulationData\ConsoleTest')
cavs.add_cavity(pill, 'pillbox')
# Out:
# Project D:\Dropbox\CavityDesignHub\MuCol_Study\SimulationData\ConsoleTest created successfully/already exists.

# %%
cavs.run_eigenmode('ngsolve', rerun=True)
pp.pprint(cavs.eigenmode_qois)
# Out:
# {   'pillbox': {   'Bpk [mT]': 6.023155403195325e-05,
#                    'Bpk/Eacc [mT/MV/m]': 19.702547731821536,
#                    'Eacc [MV/m]': 3.05704393420519e-06,
#                    'Epk [MV/m]': 4.092846032897805e-05,
#                    'Epk/Eacc []': 13.38824734281065,
#                    'G [Ohm]': 694.8435647568715,
#                    'GR/Q [Ohm^2]': 18252.864735408202,
#                    'Hpk [A/m]': 0.0479307477714597,
#                    'N Cells': 1,
#                    'Normalization Length [mm]': 620,
#                    'Q []': 96517.80591817376,
#                    'R/Q [Ohm]': 26.2690275354208,
#                    'Req [mm]': 148,
#                    'Rsh [MOhm]': 2.535428901322907,
#                    'Vacc [MV]': 1.8953672392072179e-06,
#                    'ff [%]': 100.0,
#                    'freq [MHz]': 782.4304088810633,
#                    'kcc [%]': 0.0}}

# %%
# plot mesh and fields
cavs.cavities_list[0].plot_mesh(plotter='matplotlib')

# %%
cavs.cavities_list[0].plot_fields(mode=1, plotter='matplotlib')

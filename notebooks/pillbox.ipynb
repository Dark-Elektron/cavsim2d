# %%
import sys
sys.path.append("..")
import numpy as np
import json
import matplotlib
import matplotlib.pyplot as plt
plt.ion()
# %matplotlib inline
from cavsim2d.cavity import Cavity, Cavities, OperationPoints, Pillbox
import pprint
pp = pprint.PrettyPrinter(indent=4)
# Out:
# <style>p{background: -webkit-linear-gradient(#eee, #333);-webkit-background-clip: text; webkit-text-fill-color: transparent; }</style> <p><b>CAV-SIM-2D</b> loaded successfully!</p>

# %%
# pillbox parameters
n_cell, L, Req, Ri, S, L_bp, beampipe = 1, 310, 148, 48, 92, 92, 'both'

# create cavity
pill = Pillbox(n_cell, L, Req, Ri, S, L_bp, beampipe)
ax = pill.plot('geometry')

plt.show()

# %%
cavs = Cavities([])
# must first save cavities
cavs.save('D:\Dropbox\CavityDesignHub\MuCol_Study\SimulationData\ConsoleTest')
cavs.add_cavity(pill, 'pillbox')
# Out:
# Project D:\Dropbox\CavityDesignHub\MuCol_Study\SimulationData\ConsoleTest created successfully/already exists.

# %%
cavs.run_eigenmode('ngsolve', rerun=True)
pp.pprint(cavs.eigenmode_qois)
# Out:
# {   'pillbox': {   'Bpk [mT]': 6.0231554076958414e-05,
#                    'Bpk/Eacc [mT/MV/m]': 19.702547783356408,
#                    'Eacc [MV/m]': 3.0570439284932783e-06,
#                    'Epk [MV/m]': 4.092846028681855e-05,
#                    'Epk/Eacc []': 13.388247354034888,
#                    'G [Ohm]': 694.843566521136,
#                    'GR/Q [Ohm^2]': 18252.864713548064,
#                    'Hpk [A/m]': 0.04793074780727367,
#                    'N Cells': 1,
#                    'Normalization Length [mm]': 620,
#                    'Q []': 96517.80616324025,
#                    'R/Q [Ohm]': 26.269027437261077,
#                    'Req [mm]': 148,
#                    'Rsh [MOhm]': 2.5354288982864044,
#                    'Vacc [MV]': 1.8953672356658326e-06,
#                    'ff [%]': 100.0,
#                    'freq [MHz]': 782.4304088810649,
#                    'kcc [%]': 0.0}}

# %%
# plot mesh and fields
cavs.cavities_list[0].plot_mesh()
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…

# %%
cavs.cavities_list[0].plot_fields(mode=1)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…
